# %%
import pandas as pd

# %%
df = pd.read_excel('./미니프로젝트-쇼핑몰 실습데이터.xlsx')

# %%
df = df.drop(columns = (['초도상품', '제작문구 내역']))

# %%
df = df.query('처리상태 == "구매확정"')

# %%
df
# Out:
#                    주문번호   업체명                          상품명   제조사  주문수량   판매금액  \
# 0       191213170236874    지니    eHBM셀파수학교실 비닐봉투-1세트 100장입    HB     1   5000
# 1       191216100347429    지니    eHBM셀파수학교실 비닐봉투-1세트 100장입    HB     1   5000
# 2       191216100347429    지니     eHBM셀파수학교실 삼색볼펜-1세트 50개입    HB     3  67500
# 3       191216173241622    지니  eHBM셀파수학교실 회원용 리플렛-1세트 50권입    HB     2  30000
# 4       191216173241622    지니      eHBM셀파수학교실-학습계통도(중등 5종)    HB     1    750
# ...                 ...   ...                          ...   ...   ...    ...
# 217852  221106231538662  다우기술            [올리브영] 기프트카드 1만원권  올리브영     2  19200
# 217914  221107074704768  다우기술    [따뜻달달특가] 빽다방-빽′s카페라떼(HOT)   빽다방     1   2550
# 217927  221107081217959  다우기술          [GS25] 모바일 상품권 2천원권  GS25     1   1800
# 217938  221107083418760  다우기술            [이디야] 연유 카페라떼 HOT   이디야     1   3400
# 217940  221107090224476  다우기술      [따뜻달달특가] 빽다방-앗메리카노(HOT)   빽다방     1   1300
#
# ...

# %%
df['연도'] = df['주문일자'].dt.year
df['월'] = df['주문일자'].dt.month

# %%
df['업체수'] =df['연도'].map(unique_counts)
df
# Out:
#                    주문번호   업체명                          상품명   제조사  주문수량   판매금액  \
# 0       191213170236874    지니    eHBM셀파수학교실 비닐봉투-1세트 100장입    HB     1   5000
# 1       191216100347429    지니    eHBM셀파수학교실 비닐봉투-1세트 100장입    HB     1   5000
# 2       191216100347429    지니     eHBM셀파수학교실 삼색볼펜-1세트 50개입    HB     3  67500
# 3       191216173241622    지니  eHBM셀파수학교실 회원용 리플렛-1세트 50권입    HB     2  30000
# 4       191216173241622    지니      eHBM셀파수학교실-학습계통도(중등 5종)    HB     1    750
# ...                 ...   ...                          ...   ...   ...    ...
# 217852  221106231538662  다우기술            [올리브영] 기프트카드 1만원권  올리브영     2  19200
# 217914  221107074704768  다우기술    [따뜻달달특가] 빽다방-빽′s카페라떼(HOT)   빽다방     1   2550
# 217927  221107081217959  다우기술          [GS25] 모바일 상품권 2천원권  GS25     1   1800
# 217938  221107083418760  다우기술            [이디야] 연유 카페라떼 HOT   이디야     1   3400
# 217940  221107090224476  다우기술      [따뜻달달특가] 빽다방-앗메리카노(HOT)   빽다방     1   1300
#
# ...

# %%
df.query("업체명 == '오피스퀵'")['상품명'].unique()
# Out:
# array(['[복사용지]페이지 A4 75g 1BOX(2500매)', '[복사용지]밀크 A4 75g 1BOX(2500매)',
#        '[복사용지]케이파피 A4 75g 1BOX(2500매)',
#        '[복사용지]더블에이 실속형 A4 80g 1BOX(2000매)',
#        '[복사용지]삼성프리미엄 A4 75g 1BOX(2500매)', '[복사용지]밀크 A4 80g 1BOX(2500매)',
#        '[복사용지]케이파피 A4 80g 1BOX(2500매)', '[복사용지]페이지 A4 80g 1BOX(2500매)',
#        '[복사용지]하이브라이트 A4 80g 1BOX(2500매)',
#        '[복사용지]중질지 A4 70g(미색) 1BOX(2500매)',
#        '[복사용지]더블에이 A4 80g 1BOX(2500매)', '[복사용지]한솔 A4 75g 1BOX(2500매)',
#        '[복사용지]HP A4 75g 1BOX(2500매)', '[복사용지]밀크 실속형 A4 75g 1BOX (2000매) ',
#        '[복사용지]하이플러스 B5 75g 1BOX(2500매)',
#        '[복사용지]삼성프리미엄 A4 80g 1BOX(2500매)', '[복사용지]스펙트라 칼라복사지 A4 80g 1BOX',
#        '[특가/무배] 무림 하이브라이트 A4 75g 1Box(2,500매입)',
#        '[복사용지]한솔 A4 80g 1BOX(2500매)', '[복사용지]밀크 A4 85g 1BOX(2500매)',
#        '[복사용지]하이플러스 A4 75g 1BOX(2500매)', '[복사용지]미스터카피 A4 80g 1BOX(2500매)',
#        '[복사용지]스마티스트 A4 75g 1BOX(2500매)', '[복사용지]신문 A4 54g 1BOX(2500매)',
# ...

# %%
df.query("업체명 == '쥬크박스'")['상품명'].unique()
# Out:
# array(['[학생선물] 매직 시크릿 펜', '[학생선물] 빙글빙글 도형자세트', '[학생선물] 오늘의 타로카드', ...,
#        '[학생선물] 700 프로펠러 2P-24개입', '[학생선물] 슈즈카 (랜덤발송)',
#        '[학생선물] 요술반지 (랜덤발송)'], dtype=object)

# %%
df1 = df.groupby(['연도', '업체수','업체명']).agg({'판매금액':'sum'}).sort_values(by=['연도', '판매금액'], ascending=False)

# %%
df1 = df1.reset_index(level = 1)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 df1.groupby(['연도'])[['업체명','판매금액']].shape90
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:952, in GroupBy.__getattr__(self, attr)
#     949 if attr in self.obj:
#     950     return self[attr]
# --> 952 raise AttributeError(
#     953     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'shape90'

# %%
df1.query('연도 == 2022').head(10)
# Out:
#                     연도        판매금액
# 업체수 업체명
# 65  다우기술          2022  1703529790
#     지니 태블릿(후불집행)  2022  1001880000
#     천재태블릿         2022   967032000
#     지니            2022   335132215
#     에이스디포         2022    74152300
#     오피스퀵          2022    64963100
#     쥬크박스          2022    48268080
#     블루스톤익스체인지     2022    26191900
#     알파            2022    15467900
#     거영아이앤디        2022    11921230

# %%
df1.query('연도 == 2021').head(10)
# Out:
#                  연도       판매금액
# 업체수 업체명
# 53  다우기술       2021  992927854
#     지니 태블릿     2021  604692000
#     천재태블릿      2021  426492000
#     지니         2021  310319960
#     에이스디포      2021  107867400
#     오피스퀵       2021   78630800
#     라온웍스       2021   50533670
#     블루스톤익스체인지  2021   20825600
#     더싸다닷컴      2021   18667800
#     쥬크박스       2021   17917920

# %%
df1.query('연도 == 2020').head(10)
# Out:
#                연도       판매금액
# 업체수 업체명
# 57  지니 태블릿   2020  548528000
#     지니       2020  216408095
#     라온웍스     2020   50151550
#     에이스디포    2020   41176500
#     오피스퀵     2020   33212200
#     다우기술     2020   32360110
#     조이스      2020   11873110
#     가이스파트너스  2020    9415600
#     빅픽처      2020    8580800
#     쥬크박스     2020    8334710

# %%
df1.query('연도 == 2019')
# Out:
#             연도     판매금액
# 업체수 업체명
# 4   지니    2019  4100600
#     라온웍스  2019   446100
#     쥬크박스  2019   278980
#     조이스   2019   181900

# %%
df2= df1.reset_index()
# Out:
#      업체수           업체명    연도        판매금액
# 0     65          다우기술  2022  1703529790
# 1     65  지니 태블릿(후불집행)  2022  1001880000
# 2     65         천재태블릿  2022   967032000
# 3     65            지니  2022   335132215
# 4     65         에이스디포  2022    74152300
# ..   ...           ...   ...         ...
# 174   57         셀러테스트  2020       10000
# 175    4            지니  2019     4100600
# 176    4          라온웍스  2019      446100
# 177    4          쥬크박스  2019      278980
# 178    4           조이스  2019      181900
#
# [179 rows x 4 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='AppleGothic'
sns.barplot(x='연도', y='업체수', data=df2)
plt.title('연도에 따른 입점 업체 수')
plt.show()
